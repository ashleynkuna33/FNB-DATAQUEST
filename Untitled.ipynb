# %%
import pandas as pd

# %%
data = pd.read_csv("loan_book.csv")

# %%
data
# Out:
#        applicant_id_hash   age  annual_income  employment_length_years  \
# 0       11a2f242b28a331c  35.5        29401.0                      3.6
# 1       5afff059dc04c6f0  25.0        32005.0                      1.4
# 2       eb85b183be0505f3  40.0        26730.0                      NaN
# 3       7d99629563bdb528  30.9        60105.0                      7.5
# 4       658f1f05e484ce14  49.1       112275.0                      6.9
# ...                  ...   ...            ...                      ...
# 120955  f72c2a5472b39f2a  24.0        80416.0                      3.3
# 120956  88b6b962fbd4c70d  21.0            NaN                      1.8
# 120957  8c9f6907e46e6149  53.8        45310.0                      7.2
# 120958  0a454eafda417eea  21.0       109110.0                      1.4
# 120959  d414dd036037ed87  26.5       128962.0                      0.3
#
#        home_ownership          region  num_open_accounts  \
# ...
